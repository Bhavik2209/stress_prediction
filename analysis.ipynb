# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
plt.pie(df['Gender'].value_counts(),autopct='%d%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x215abfda000>,
# ...
#  [Text(-0.01847914257177896, 1.0998447714517772, ''),
#   Text(0.018479245546678402, -1.0998447697216303, '')],
#  [Text(-0.010079532311879432, 0.5999153298827875, '50%'),
#   Text(0.010079588480006401, -0.599915328939071, '49%')])

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
age = df['Age']
age.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Gender'].value_counts().reset_index()
# Out:
#    Gender  count
# 0    Male    189
# 1  Female    185

# %%
df['Gender'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Gender'>

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
occupation_counts = df['Occupation'].value_counts()

# Extracting labels and counts
labels = occupation_counts.index
counts = occupation_counts.values

plt.pie(counts, labels=labels, autopct='%0.1f%%')
plt.show()

# %%
occupation_counts = df['Occupation'].value_counts()

# Extracting labels and counts
labels = occupation_counts.index
counts = occupation_counts.values

plt.barh(labels,counts)
plt.show()

# %%
df['Sleep Duration'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 374 entries, 0 to 373
# Series name: Sleep Duration
# Non-Null Count  Dtype
# --------------  -----
# 374 non-null    float64
# dtypes: float64(1)
# memory usage: 3.1 KB

# %%
sleep = df['Sleep Duration']
sleep.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
# Correlation heatmap
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
# plt.title('Correlation Heatmap')
# plt.show()

# Distribution of Sleep Duration
plt.figure(figsize=(10, 6))
sns.histplot(df['Sleep Duration'], bins=10, kde=True)
plt.title('Distribution of Sleep Duration')
plt.xlabel('Sleep Duration (hours)')
plt.ylabel('Frequency')
plt.show()

# Distribution of Quality of Sleep
plt.figure(figsize=(10, 6))
sns.histplot(df['Quality of Sleep'], bins=5, kde=True)
plt.title('Distribution of Quality of Sleep')
plt.xlabel('Quality of Sleep')
plt.ylabel('Frequency')
plt.show()

# Boxplot of Heart Rate by Gender
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Heart Rate', data=df)
plt.title('Boxplot of Heart Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Heart Rate')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Occupation', data=df, palette='Set2')
plt.title('Occupation Distribution')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# BMI Category Distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='BMI Category', data=df, palette='Pastel1')
plt.title('BMI Category Distribution')
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.show()

# Sleep Disorder Frequency
plt.figure(figsize=(8, 6))
sns.countplot(y='Sleep Disorder', data=df, palette='Paired')
plt.title('Sleep Disorder Frequency')
plt.xlabel('Count')
plt.ylabel('Sleep Disorder')
plt.show()

# Physical Activity Level vs. Daily Steps
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Physical Activity Level', y='Daily Steps', data=df, hue='Gender', palette='Set1')
plt.title('Physical Activity Level vs. Daily Steps')
plt.xlabel('Physical Activity Level')
plt.ylabel('Daily Steps')
plt.show()

# Stress Level by Occupation
plt.figure(figsize=(10, 6))
sns.boxplot(x='Occupation', y='Stress Level', data=df)
plt.title('Stress Level by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Stress Level')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SVI\AppData\Local\Temp\ipykernel_385016\4092647609.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Occupation', data=df, palette='Set2')
# C:\Users\SVI\AppData\Local\Temp\ipykernel_385016\4092647609.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='BMI Category', data=df, palette='Pastel1')
# C:\Users\SVI\AppData\Local\Temp\ipykernel_385016\4092647609.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Sleep Disorder', data=df, palette='Paired')

# %%
# Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=10, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Blood Pressure Distribution
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['Blood Pressure'].apply(lambda x: int(x.split('/')[0])), bins=10, kde=True, color='blue')
plt.title('Systolic Blood Pressure Distribution')
plt.xlabel('Systolic Blood Pressure')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df['Blood Pressure'].apply(lambda x: int(x.split('/')[1])), bins=10, kde=True, color='green')
plt.title('Diastolic Blood Pressure Distribution')
plt.xlabel('Diastolic Blood Pressure')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Relationship between Sleep Duration and Quality of Sleep
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sleep Duration', y='Quality of Sleep', data=df, hue='BMI Category', palette='Set1')
plt.title('Relationship between Sleep Duration and Quality of Sleep')
plt.xlabel('Sleep Duration (hours)')
plt.ylabel('Quality of Sleep')
plt.show()

# Heart Rate Distribution by BMI Category
plt.figure(figsize=(10, 6))
sns.boxplot(x='BMI Category', y='Heart Rate', data=df, palette='Set3')
plt.title('Heart Rate Distribution by BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Heart Rate')
plt.show()

# Comparison of Daily Steps by Gender
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Daily Steps', data=df, ci=None, palette='coolwarm')
plt.title('Comparison of Daily Steps by Gender')
plt.xlabel('Gender')
plt.ylabel('Daily Steps')
plt.show()
# Out:
# C:\Users\SVI\AppData\Local\Temp\ipykernel_385016\377030390.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='BMI Category', y='Heart Rate', data=df, palette='Set3')
# C:\Users\SVI\AppData\Local\Temp\ipykernel_385016\377030390.py:44: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Gender', y='Daily Steps', data=df, ci=None, palette='coolwarm')
# C:\Users\SVI\AppData\Local\Temp\ipykernel_385016\377030390.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Daily Steps', data=df, ci=None, palette='coolwarm')
